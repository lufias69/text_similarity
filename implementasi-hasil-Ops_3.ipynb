# %% [markdown]
# # Import Modul

# %%
import pandas as pd
from Nawa import nawa
from Nawa import ngram
#import re

# %% [markdown]
# ## Menghitung Similarity

# %%
#TF_IDF_DF
def essay_similarity_jaccard_tf_idf_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf_df(kj, jawaban, fitur)
        jaccard = nawa.jaccard_baru(t.A[0], t.A[1])
        simm.append(jaccard)
    return max(simm)

def essay_similarity_cosine_tf_idf_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf_df(kj, jawaban, fitur)
        cosine = nawa.cosine_similarity(t.A[0], t.A[1])
        simm.append(cosine)
    return max(simm)

def essay_similarity_dice_tf_idf_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf_df(kj, jawaban, fitur)
        dice = nawa.dice_similarity(t.A[0], t.A[1])
        simm.append(dice)
    return max(simm)

#TF_IDF
def essay_similarity_jaccard_tf_idf(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf_df(kj, jawaban, fitur)
        jaccard = nawa.jaccard_baru(t.A[0], t.A[1])
        simm.append(jaccard)
    return max(simm)

def essay_similarity_cosine_tf_idf(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf(kj, jawaban, fitur)
        cosine = nawa.cosine_similarity(t.A[0], t.A[1])
        simm.append(cosine)
    return max(simm)

def essay_similarity_dice_tf_idf(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.tf_idf(kj, jawaban, fitur)
        dice = nawa.dice_similarity(t.A[0], t.A[1])
        simm.append(dice)
    return max(simm)

#DF
def essay_similarity_jaccard_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.df(kj, jawaban, fitur)
        jaccard = nawa.jaccard_baru(t.A[0], t.A[1])
        simm.append(jaccard)
    return max(simm)

def essay_similarity_cosine_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.df(kj, jawaban, fitur)
        cosine = nawa.cosine_similarity(t.A[0], t.A[1])
        simm.append(cosine)
    return max(simm)

def essay_similarity_dice_df(kunci_jawaban_negasi_list, jawaban):
    if type(kunci_jawaban_negasi_list) != list:
        kunci_jawaban_negasi_list = [kunci_jawaban_negasi_list]
    simm = list()   
    for kj in kunci_jawaban_negasi_list:
        fitur = list(set(nawa.cek_negasi(kata_negasi, kj).split()))
        #print(fitur)
        t = nawa.df(kj, jawaban, fitur)
        dice = nawa.dice_similarity(t.A[0], t.A[1])
        simm.append(dice)
    return max(simm)

def transform(simmm):
    if simmm <= 0.25:
        return "sangat tidak mirip"
    elif simmm <= 0.5:
        return "tidak mirip"
    elif simmm <= 0.75:
        return "mirip"
    elif simmm <= 1:
        return "sangat mirip"
    else:
        return "error"

# %%
#Kata Negasi (bisa di-update)
kata_negasi = ["tidak", "bukan","tiada","tak", "jangan"]

# %% [markdown]
# # Load Jawaban

# %%
#data = pd.read_excel("data/jawaban_hasil_evaluasi_ahli.xlsx")
#jawaban_ = data['jawaban_tanpa_stem'].tolist()
#data.head()
#jawaban_ = jawaban_[311:314]

# %%
#data = pd.read_excel("data/jawaban_clean_jawaban buat label_1.xlsx")
data = pd.read_excel("data/jawaban_clean_jawaban buat label_1.xlsx")
data = data[:100]
jawaban_ = data['jawaban_tanpa_stem'].tolist()
#jawaban_ = data['jawaban'].tolist()
#score = data['score']
#data.head()
print("selesai load data")
# Out:
# selesai load data

# %% [markdown]
# # Input kunci jawaban

# %%
#kunci_jawaban = [#"telepon 02173811111 kunjungi website buanawisata.com",
                 #"02173811111 buanawisata.com",
                #]
#hanya untuk testing
#jawaban = "tidakk kunjunngi 1telepon0217381 1111 2 kunjungi website kami di buanawisata.com"

# %% [markdown]
# # Implementasi

# %% [markdown]
# # Praproses

# %%
def cek_negasi_list(kunci_jawaban):
    if type(kunci_jawaban) is not list:
        kunci_jawaban = [kunci_jawaban]
    new_kj = list()
    for i in kunci_jawaban:
        i = nawa.ubah_simbol(i)
        hasil = nawa.cek_negasi(kata_negasi,i)
        new_kj.append(hasil)
    return new_kj
#cek_negasi_list("tidak telepon pada 02173811111 website buanawisata.com")

def get_unik(kunci_jawaban):
    if type(kunci_jawaban) is not list:
        kunci_jawaban = [kunci_jawaban]
    list_kata_kj = list()
    for i in kunci_jawaban:
        i = nawa.ubah_simbol(i)
        for j in i.split():
            list_kata_kj.append(j)
    list_kata_kj = list(set(list_kata_kj))
    return list_kata_kj

def praproses(jawaban, kunci_jawaban_unik):
    jawaban = nawa.ubah_simbol(jawaban)
    jawaban = nawa.pisahKata(kunci_jawaban_unik, jawaban)
    jawaban_ngram = ngram.en_geram(kunci_jawaban_unik, jawaban).split()
    #jawaban = jawaban +" "+ " ".join(list(set(jawaban_ngram.split())))
    jawaban = jawaban.split()
    for i in jawaban_ngram:
        if i not in jawaban:
            jawaban.append(i)
    jawaban = " ".join(jawaban)
    jawaban = nawa.cek_typo(kunci_jawaban_unik, jawaban, 0.95)
    jawaban = nawa.cek_negasi(kata_negasi, jawaban)
    return jawaban

#praproses("buanawisata.com", kunci_jawaban_unik)

# %% [markdown]
# ## Persiapan data

# %%
kunci_jawaban = ["telepon 02173811111 kunjungi website buanawisata.com",
                 "02173811111 buanawisata.com",
                ]
#hanya untuk testing
jawaban = "tidakk kunjunngi 1telepon0217381 1111 2 kunjungi website kami di buanawisata.com"

nega = cek_negasi_list(kunci_jawaban)
fitur = get_unik(nega)

kunci_jawaban_unik = " ".join(get_unik(kunci_jawaban))

jawaban_praproses = praproses(jawaban, kunci_jawaban_unik)
kunci_jawaban_negasi_list = cek_negasi_list(kunci_jawaban)
nega = cek_negasi_list(kunci_jawaban)
fitur = 0
print("fitur         ->",fitur)
print("Kunci Jawaban ->",kunci_jawaban_negasi_list)
print("Jawaban       ->",jawaban_praproses)
# Out:
# fitur         -> 0
# Kunci Jawaban -> ['telepon 02173811111 kunjungi website buanawisatacom', '02173811111 buanawisatacom']
# Jawaban       -> tidak_ kunjungi 1 telepon 0217381 1111 2 kunjungi website kami di buanawisatacom 02173811111

# %% [markdown]
# ## Proses Perhitungan Similarity

# %%
jawaban_cektypo = []
tf_idf_jaccard = []
tf_idf_cosine = []
tf_idf_dice = []

tf_idf_df_jaccard = []
tf_idf_df_cosine = []
tf_idf_df_dice = []

df_jaccard = []
df_cosine = []
df_dice = []
ct =0

dice_list_t_tfidf = list()
jaccard_list_t_tfidf = list()
cosine_list_t_tfidf = list()

dice_list_t_tfidfdf = list()
jaccard_list_t_tfidfdf = list()
cosine_list_t_tfidfdf = list()

dice_list_t_df = list()
jaccard_list_t_df = list()
cosine_list_t_df = list()

for i in jawaban_:
    i = praproses(i, kunci_jawaban_unik)
    jaccard = essay_similarity_jaccard_tf_idf_df(kunci_jawaban_negasi_list, i)
    cosine = essay_similarity_cosine_tf_idf_df(kunci_jawaban_negasi_list, i)
    dice = essay_similarity_dice_tf_idf_df(kunci_jawaban_negasi_list, i)
    tf_idf_df_jaccard.append(jaccard)
    tf_idf_df_cosine.append(cosine)
    tf_idf_df_dice.append(dice)
    jaccard_list_t_tfidfdf.append(transform(jaccard))
    cosine_list_t_tfidfdf.append(transform(cosine))
    dice_list_t_tfidfdf.append(transform(dice))
        
    jaccard = essay_similarity_jaccard_tf_idf(kunci_jawaban_negasi_list, i)
    cosine = essay_similarity_cosine_tf_idf(kunci_jawaban_negasi_list, i)
    dice = essay_similarity_dice_tf_idf(kunci_jawaban_negasi_list, i)
    tf_idf_jaccard.append(jaccard)
    jaccard_list_t_tfidf.append(transform(jaccard))
    tf_idf_cosine.append(cosine)
    cosine_list_t_tfidf.append(transform(cosine))
    tf_idf_dice.append(dice)
    dice_list_t_tfidf.append(transform(dice))
    
    jaccard = essay_similarity_jaccard_df(kunci_jawaban_negasi_list, i)
    cosine = essay_similarity_cosine_df(kunci_jawaban_negasi_list, i)
    dice = essay_similarity_dice_df(kunci_jawaban_negasi_list, i)
    df_jaccard.append(jaccard)
    df_cosine.append(cosine)
    df_dice.append(dice)
    jaccard_list_t_df.append(transform(jaccard))
    cosine_list_t_df.append(transform(cosine))
    dice_list_t_df.append(transform(dice))
    
dict1 = {"jawaban":jawaban_,
         "tf_idf_dice":tf_idf_dice,
        "tf_idf_jaccard":tf_idf_jaccard, 
        "tf_idf_cosine":tf_idf_cosine,
        "tf_idf_tf_dice":tf_idf_df_dice,
       "tf_idf_tf_jaccard":tf_idf_df_jaccard,
        "tf_idf_tf_cosine":tf_idf_df_cosine,
        "tf_dice":df_dice,
        "tf_jaccard":df_jaccard,
        "tf_cosine":df_cosine
       }

dic2 = {
    "jawaban":jawaban_,
    "dice_tf-idf":dice_list_t_tfidf,
    "jaccard_tf-idf":jaccard_list_t_tfidf,
    "cosine_tf-idf":cosine_list_t_tfidf,

    "dice_tf-idf-tf":dice_list_t_tfidfdf,
    "jaccard_tf-idf-tf":jaccard_list_t_tfidfdf,
    "cosine_tf-idf-tf":cosine_list_t_tfidfdf,

    "dice_tf":dice_list_t_df,
    "jaccard_tf":jaccard_list_t_df,
    "cosine_tf":cosine_list_t_df
}

dict3 = {
    "jawaban":jawaban_,
    "tf_idf_dice":tf_idf_dice,
    "dice_tf-idf":dice_list_t_tfidf,
    "tf_idf_jaccard":tf_idf_jaccard,
    "jaccard_tf-idf":jaccard_list_t_tfidf,
    "tf_idf_cosine":tf_idf_cosine,
    "cosine_tf-idf":cosine_list_t_tfidf,
    "tf_idf_tf_dice":tf_idf_df_dice,
    "dice_tf-idf-tf":dice_list_t_tfidfdf,
    "tf_idf_tf_jaccard":tf_idf_df_jaccard,
    "jaccard_tf-idf-tf":jaccard_list_t_tfidfdf,
    "tf_idf_tf_cosine":tf_idf_df_cosine,
    "cosine_tf-idf-tf":cosine_list_t_tfidfdf,
    "tf_dice":df_dice,
    "dice_tf":dice_list_t_df,
    "tf_jaccard":df_jaccard,
    "jaccard_tf":jaccard_list_t_df,
    "tf_cosine":df_cosine,
    "cosine_tf":cosine_list_t_df
}
df1 = pd.DataFrame.from_dict(dict1)
df2 = pd.DataFrame.from_dict(dic2)
df3 = pd.DataFrame.from_dict(dict3)
df3.head()
# Out:
#             cosine_tf       cosine_tf-idf    cosine_tf-idf-tf  \
# 0               mirip               mirip               mirip
# 1        sangat mirip        sangat mirip        sangat mirip
# 2               mirip               mirip               mirip
# 3        sangat mirip        sangat mirip        sangat mirip
# 4  sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
#
#               dice_tf         dice_tf-idf      dice_tf-idf-tf  \
# 0               mirip               mirip               mirip
# 1        sangat mirip        sangat mirip        sangat mirip
# 2               mirip               mirip               mirip
# 3        sangat mirip        sangat mirip        sangat mirip
# 4  sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
#
#            jaccard_tf      jaccard_tf-idf   jaccard_tf-idf-tf  \
# 0         tidak mirip         tidak mirip         tidak mirip
# 1        sangat mirip        sangat mirip        sangat mirip
# 2         tidak mirip         tidak mirip         tidak mirip
# 3        sangat mirip        sangat mirip        sangat mirip
# 4  sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
#
#                                              jawaban  tf_cosine   tf_dice  \
# 0  ayo kunjungi machu picchu yang megahsejuk dan ...      0.707  0.666667
# 1  telepon0217381 1111 untuk mengetahui info lebi...      1.000  1.000000
# 2  "pendakian dua hari bersama buana wisata ke ma...      0.707  0.666667
# 3  anda dapat menelepon 021 7381 1111 sekarang ju...      1.000  1.000000
# 4  arsitektur yang menabjub kan teras teras yang ...      0.000  0.000000
#
#    tf_idf_cosine  tf_idf_dice  tf_idf_jaccard  tf_idf_tf_cosine  \
# 0           0.58     0.579739        0.408192              0.58
# 1           1.00     1.000000        1.000000              1.00
# 2           0.58     0.579739        0.408192              0.58
# 3           1.00     1.000000        1.000000              1.00
# 4           0.00     0.000000        0.000000              0.00
#
#    tf_idf_tf_dice  tf_idf_tf_jaccard  tf_jaccard
# 0        0.579739           0.408192         0.5
# 1        1.000000           1.000000         1.0
# 2        0.579739           0.408192         0.5
# 3        1.000000           1.000000         1.0
# 4        0.000000           0.000000         0.0

# %%
pd.value_counts(df2['dice_tf-idf']).plot.bar(title='Hasil Prediksi')
pd.value_counts(df2['dice_tf-idf'])
#df2['dice_tf-idf']
# Out:
# sangat mirip          46
# sangat tidak mirip    27
# mirip                 23
# tidak mirip            4
# Name: dice_tf-idf, dtype: int64

# %%
import datetime
waktu = str(datetime.datetime.now()).replace(":","-")
writer = pd.ExcelWriter('hasil\pelabelan\hasil_'+waktu+'_2.xlsx', engine='xlsxwriter')
df1.to_excel(writer, sheet_name='Sheet1')
# Close the Pandas Excel writer and output the Excel file.
writer.save()

writer = pd.ExcelWriter('hasil\hasil_similarity\ops3\ops_3_hasil_transform_'+waktu+'_2_.xlsx', engine='xlsxwriter')
df2.to_excel(writer, sheet_name='Sheet1')
# Close the Pandas Excel writer and output the Excel file.
writer.save()


writer = pd.ExcelWriter('hasil\pelabelan\hasil_gabungan_'+waktu+'_2.xlsx', engine='xlsxwriter')
df3.to_excel(writer, sheet_name='Sheet1')
# Close the Pandas Excel writer and output the Excel file.
writer.save()
df2
# Out:
#              cosine_tf       cosine_tf-idf    cosine_tf-idf-tf  \
# 0                mirip               mirip               mirip
# 1         sangat mirip        sangat mirip        sangat mirip
# 2                mirip               mirip               mirip
# 3         sangat mirip        sangat mirip        sangat mirip
# 4   sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
# 5   sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
# 6   sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
# 7                mirip               mirip               mirip
# 8                mirip               mirip               mirip
# 9         sangat mirip        sangat mirip        sangat mirip
# 10        sangat mirip        sangat mirip        sangat mirip
# 11        sangat mirip        sangat mirip        sangat mirip
# 12        sangat mirip        sangat mirip        sangat mirip
# 13        sangat mirip        sangat mirip        sangat mirip
# 14        sangat mirip        sangat mirip        sangat mirip
# 15        sangat mirip        sangat mirip        sangat mirip
# 16        sangat mirip        sangat mirip        sangat mirip
# 17        sangat mirip        sangat mirip        sangat mirip
# 18        sangat mirip        sangat mirip        sangat mirip
# 19        sangat mirip        sangat mirip        sangat mirip
# 20  sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
#
sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
# 97  sangat tidak mirip  sangat tidak mirip  sangat tidak mirip
# 98        sangat mirip        sangat mirip        sangat mirip
# 99         tidak mirip         tidak mirip         tidak mirip
#
#                                               jawaban
# 0   ayo kunjungi machu picchu yang megahsejuk dan ...
# 1   telepon0217381 1111 untuk mengetahui info lebi...
# 2   "pendakian dua hari bersama buana wisata ke ma...
# 3   anda dapat menelepon 021 7381 1111 sekarang ju...
# 4   arsitektur yang menabjub kan teras teras yang ...
# 5   berbagai perjalanan wisata yang akan membantu ...
# 6   berkunjunglah selama beberapa hari atau tingga...
# 7   biro perjalanan buana wisata menawaekanbwerbag...
# 8   biro perjalanan buana wisata menawarka berbaga...
# 9   telepon021 7381 1111 untuk informasi lebih lan...
# 10  telepon0217381 1111 atau kunjungi website kami...
# 11  telepon0217381 1111 kunjungi webisite di buana...
# 12  telepon0217381 1111 sekarang juga untuk inform...
# 13  telepon0217381 1111 sekarang jugauntuk informa...
# 14  telepon0217381 1111 untuk informasi lebih lanj...
# 15  telepon02173811111 informasi lebih lanjutatau ...
# 16  telepon02173811111 kunjungi website kami di bu...
# 17  telpon 021 7381 1111 sekarang juga untuk infor...
# 18  telpon 021 7381 1111 sekarang juga untuk infor...
# 19  telpon 021 7381 1111 sekrang juga untuk inform...
# 20  wisata menawarkan berbagai perjalanan wisata y...
# 21  wisata yg akan mengujungi kota kuno machu picc...
# 22  wisatawan akan diajak ke kuil bulan dimana tem...
# 23  wisatawan dapat menelpon kenomor 021 7381 1111...
# 24  yaitu dengan di terangkan oleh pemandu machu p...
# 25  yaitu dengan menelepon pada nomor 0217381 1111...
# 26  yaitu dengan telepon ke nomor 02173811111 dan ...
# 27  yaitu membawa anda dari cuzco ke machu picchu ...
# 28  "pendakian dua hari bersama buana wisata ke ma...
# 29      021 7381 1111 website kami di buanawisata.com
# ..                                                ...
# 70  telepon nomor 021 7381 1111 untuk informasi le...
# 71  telepon<021>73811111 kunjungi website di buana...
# 72  telepon021 7381 1111 kunjungi website kami di ...
# 73  telepon021 7381 1111 sekarang juga untuk infor...
# 74  telepon0217381 1111 kunjungi website kami di b...
# 75  telepon0217381 1111 untuk informasi lebih lanj...
# 76  telepon02173811111 sekarang juga untuk informa...
# 77  telepon02173811111 sekarang juga untuk informa...
# 78  telepon02173811111 sekarang juga untuk informa...
# 79  telpon 021 7381 1111 sekarang juga untuk infor...
# 80  wisata yang akan membantu mengubah kota batu y...
# 81  wisatawan dapat menghubungi telepon 021 7381 1...
# 82  wisatawan yang akan mengunjungi kota kuno mach...
# 83  yaitu dengan cara menelepon nomor biro perjala...
# 84  yaitu dengan menelpon nomor yang telah di sedi...
# 85  yaitu telepon no 021 7381 1111 kunjungi websit...
# 86  " saya terkesan dengan pelayanan yang baik ole...
# 87  021 7381 1111 sekarang juga untuk informasi le...
# 88  berkunjunglah selam satu hari atau tinggallah ...
# 89  biro berjalan buatan wisata menawarkan berbaga...
# 90  biro perjalaanan busana menawarkan paket perja...
# 91  biro perjalana buana wisata menawarkan berbaga...
# 92  biro perjalanan buana wisata menawarkan akan m...
# 93  telepon021 7381 1111 kunjungi website kami di ...
# 94  telepon021738 1111 sekarang jugauntuk info leb...
# 95  telepon0217381 1111 kunjungi website di buanaw...
# 96  wisatawan bisa mencari informasi di pemandu ya...
# 97  wisatawan dapat memilih tur dengan berjalan ka...
# 98  yaitu bisa telepon di no 021 7381 1111 yaitu b...
# 99  yaitu menelfon biro perjalanan dengan no yang ...
#
# [100 rows x 10 columns]
